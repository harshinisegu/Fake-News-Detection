# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re 
import joblib
import string

# %%
fake=pd.read_csv('Fake.csv')
true=pd.read_csv('True.csv')

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake['class']=0
true['class']=1

# %%
data=pd.concat([fake,true],axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 5530   Abe hopes to avoid landing in rough in golf ou...
# 14004  U.S. Navy halts search for three sailors lost ...
# 12919  Extremism stems from repressive states, not We...
# 6399   Tillerson calls Mexico long-standing friend of...
# 20800  FBI INVESTIGATION Into HILLARY’S Email Server ...
# 21390  Pakistan rejects role of 'scapegoat for U.S. f...
# 23386  FLASHBACK: Florida Couple Nearly ‘Forecloses’ ...
# 18214  U.N. blacklists Saudi-led coalition for killin...
# 10715       Trump on rival Bush's exit: Don't look at me
# 4171   Trump and Cuba should start dialogue: Mississi...
#
#                                                     text       subject  \
# 5530   (Reuters) - With golf long regarded as a stern...  politicsNews
# 14004  TOKYO (Reuters) - A U.S. Navy said it has call...     worldnews
# 12919  LONDON (Reuters) - Repressive states are to bl...     worldnews
# 6399   WASHINGTON (Reuters) - U.S. Secretary of State...  politicsNews
# 20800  Perhaps the pundits should start changing cour...     left-news
# 21390  KARACHI, Pakistan (Reuters) - Pakistan has rej...     worldnews
# 23386  21st Century Wire says After the great crash o...   Middle-east
# 18214  UNITED NATIONS (Reuters) - The United Nations ...     worldnews
# 10715  WASHINGTON (Reuters) - Republican presidential...  politicsNews
# 4171   HAVANA (Reuters) - The Trump administration an...  politicsNews
#
#                      date  class
# 5530    February 9, 2017       1
# 14004  November 24, 2017       1
# 12919   December 7, 2017       1
# 6399    January 11, 2017       1
# 20800        Mar 30, 2016      0
# 21390    August 23, 2017       1
# 23386       April 5, 2016      0
# 18214    October 5, 2017       1
# 10715  February 21, 2016       1
# 4171      April 20, 2017       1

# %%
data=data.drop(["title","subject","date"],axis=1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis=1,inplace=True)

# %%
data.sample(5)
# Out:
#                                                     text  class
# 30254  (Reuters) - Donald Trump was scheduled to hold...      1
# 6906   On Thursday, Bernie Sanders  wife Jane Sanders...      0
# 689    I ll admit it: I am not a huge fan of tribute ...      0
# 7206   A smart presidential candidate would immediate...      0
# 29298  WASHINGTON (Reuters) - Elaine Chao, a former t...      1

# %%
def clean_text(text):
    text=text.lower()
    text=re.sub('\[.*?\]',"",text)
    text=re.sub("\\W"," ",text)
    text=re.sub("https?:://\S+|www\.\S+","",text)
    text=re.sub("<.*?>+","",text)
    text=re.sub("[%s]" % re.escape(string.punctuation),"",text)
    text=re.sub("\n","",text)
    text=re.sub("\w*\d\w*","",text)
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:5: SyntaxWarning: invalid escape sequence '\S'
# <>:9: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\harsh\AppData\Local\Temp\ipykernel_12452\3195903352.py:3: SyntaxWarning: invalid escape sequence '\['
#   text=re.sub('\[.*?\]',"",text)
# C:\Users\harsh\AppData\Local\Temp\ipykernel_12452\3195903352.py:5: SyntaxWarning: invalid escape sequence '\S'
#   text=re.sub("https?:://\S+|www\.\S+","",text)
# C:\Users\harsh\AppData\Local\Temp\ipykernel_12452\3195903352.py:9: SyntaxWarning: invalid escape sequence '\w'
#   text=re.sub("\w*\d\w*","",text)

# %%
data["text"]=data["text"].apply(clean_text)

# %%
x=data["text"]
y=data["class"]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
vectorizer=TfidfVectorizer()
xv_train=vectorizer.fit_transform(xtrain)
xv_test=vectorizer.transform(xtest)

# %%
lr=LogisticRegression()
lr.fit(xv_train,ytrain)
# Out:
# LogisticRegression()

# %%
prediction=lr.predict(xv_test)
lr.score(xv_test,ytest)
# Out:
# 0.9858351893095768

# %%
print(classification_report(ytest,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']

# %%
import pandas as pd

# Load both datasets
fake = pd.read_csv("Fake.csv")
true = pd.read_csv("True.csv")

fake['label'] = 0  # Fake
true['label'] = 1  # Real

# Combine
df = pd.concat([fake, true], axis=0).reset_index(drop=True)

# Save as single dataset
df.to_csv("news.csv", index=False)
print("Merged dataset saved as news.csv")
# Out:
# Merged dataset saved as news.csv
